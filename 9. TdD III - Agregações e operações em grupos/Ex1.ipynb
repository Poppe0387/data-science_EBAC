# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...         5.0
# 1      8 a 11 anos    999992.0         1.0         0.0  ...         5.0
# 2      8 a 11 anos    513205.0         2.0         0.0  ...         5.0
# 3  12 anos ou mais    231205.0         0.0         0.0  ...         4.0
# 4      8 a 11 anos    999992.0         1.0         0.0  ...         5.0
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0      1.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1      2.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2      3.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3      4.0        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4      5.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
sinasc_raw[['munResNome', 'IDADEMAE', 'IDADEPAI']]
# Out:
#                     munResNome  IDADEMAE  IDADEPAI
# 0        Alta Floresta D'Oeste        19      26.0
# 1        Alta Floresta D'Oeste        29      24.0
# 2        Alta Floresta D'Oeste        37      32.0
# 3      Alto Alegre dos Parecis        30      24.0
# 4        Alta Floresta D'Oeste        30      27.0
# ...                        ...       ...       ...
# 25212                  Vilhena        34      33.0
# 25213                  Vilhena        22       NaN
# 25214                  Vilhena        20       NaN
# 25215                Ji-Paraná        35       NaN
# 25216                      NaN        29       NaN
#
# [25217 rows x 3 columns]

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_raw.DTNASC = pd.to_datetime(sinasc_raw.DTNASC)
sinasc_raw.DTNASC
# Out:
# 0       2019-02-19
# 1       2019-02-21
# 2       2019-02-25
# 3       2019-03-20
# 4       2019-03-23
#            ...
# 25212   2019-08-20
# 25213   2019-08-20
# 25214   2019-08-20
# 25215   2019-08-20
# 25216   2019-08-20
# Name: DTNASC, Length: 25217, dtype: datetime64[ns]

# %%
sinasc_aniversario = sinasc_raw[(sinasc_raw.DTNASC.dt.day == 3) & (sinasc_raw.DTNASC.dt.month == 11)]

sinasc_aniversario = sinasc_aniversario.groupby(by=['DTNASC', 'SEXO', 'ESCMAE'])['PESO'].mean()

sinasc_aniversario
# Out:
# DTNASC      SEXO       ESCMAE
# 2019-11-03  Feminino   12 anos ou mais    3180.000000
#                        4 a 7 anos         3480.833333
#                        8 a 11 anos        3173.750000
#             Masculino  1 a 3 anos         3640.000000
#                        12 anos ou mais    3171.666667
#                        4 a 7 anos         2010.000000
#                        8 a 11 anos        3531.111111
# Name: PESO, dtype: float64

# %%
data = sinasc_aniversario.index.get_level_values(level=0).unique()[0].date()

sns.catplot(x='ESCMAE',
            y='PESO',
            data=sinasc_aniversario.reset_index(level='DTNASC',
                                                drop=True).reset_index(),
            hue='SEXO',
            kind='bar',
            order=['1 a 3 anos',
                   '4 a 7 anos',
                   '8 a 11 anos',
                   '12 anos ou mais'])
plt.xticks(rotation=50)
plt.xlabel(xlabel='Escolaridade da mãe')
plt.ylabel(ylabel='Média do peso do bebê')
plt.title(label=data.strftime('%d/%b/%Y'));

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
municipios = sinasc_raw.groupby(['munResNome'])
municipios.agg({'IDADEMAE':[('média','mean'),('mínima','min'),( 'máxima','max')], 'IDADEPAI':[('média','mean'),('mínima','min'),( 'máxima','max')]})
# Out:
#                             IDADEMAE                 IDADEPAI
#                                média mínima máxima      média mínima máxima
# munResNome
# Alta Floresta D'Oeste      25.964286     14     53  29.540717   17.0   58.0
# Alto Alegre dos Parecis    24.895425     14     41  29.179104   16.0   50.0
# Alto Paraíso               24.972851     11     42  24.800000   21.0   29.0
# Alvorada D'Oeste           25.675159     15     44  31.042254   17.0   49.0
# Ariquemes                  25.605691     13     44  30.800000   20.0   46.0
# Buritis                    25.608955     14     42  31.064516   18.0   49.0
# Cabixi                     25.543478     13     39  34.000000   19.0   47.0
# Cacaulândia                25.671233     16     42  36.333333   28.0   50.0
# Cacoal                     26.883467     14     47  30.931854   17.0   66.0
# Campo Novo de Rondônia     24.974359     13     40  30.178571   21.0   40.0
# Candeias do Jamari         25.237237     14     45  29.894737   21.0   41.0
# Castanheiras               27.281250     17     39  30.392857   17.0   43.0
# Cerejeiras                 27.264045     15     42  31.602941   19.0   52.0
# Chupinguaia                25.733871     13     42  29.961538   20.0   46.0
# Colorado do Oeste          27.688406     15     40  33.619048   23.0   53.0
# Corumbiara                 24.447368     15     37  31.000000   21.0   47.0
# Costa Marques              24.858757     12     41  30.805556   17.0   60.0
# Cujubim                    24.532995     14     42  34.000000   21.0   44.0
# Espigão D'Oeste            26.093333     14     44  31.198113   16.0   86.0
# Governador Jorge Teixeira  24.490909     13     41  29.222222   22.0   37.0
# Guajará-Mirim              25.449294     13     43  30.062500   19.0   44.0
# Itapuã do Oeste            26.064220     15     46  42.500000   25.0   73.0
# Jaru                       25.986333     12     45  32.228571   19.0   62.0
# Ji-Paraná                  26.356322     12     44  31.139130   15.0   63.0
# Machadinho D'Oeste         25.482897     13     44  31.326923   17.0   53.0
# Ministro Andreazza         27.904762     17     44  33.849315   21.0   55.0
# Mirante da Serra           26.398693     14     46  32.743243   20.0   56.0
# Monte Negro                25.535912     14     40  35.384615   20.0   55.0
# Município ignorado - RO    24.000000     24     24  22.000000   22.0   22.0
# Nova Brasilândia D'Oeste   26.214844     15     51  30.520833   20.0   48.0
# Nova Mamoré                25.444162     14     46  31.694444   19.0   43.0
# Nova União                 26.988372     16     39  30.653846   18.0   53.0
# Novo Horizonte do Oeste    27.072917     15     41  31.588235   20.0   56.0
# Ouro Preto do Oeste        26.365660     14     44  31.233244   17.0   60.0
# Parecis                    26.454545     16     41  32.473684   18.0   61.0
# Pimenta Bueno              25.215686     13     47  29.745174   16.0   70.0
# Pimenteiras do Oeste       25.444444     16     40  35.600000   25.0   45.0
# Porto Velho                26.368971     12     47  32.400000   16.0   65.0
# Presidente Médici          25.796053     14     44  30.150754   16.0   64.0
# Primavera de Rondônia      27.023256     16     39  31.888889   21.0   44.0
# Rio Crespo                 26.775510     16     39  28.000000   28.0   28.0
# Rolim de Moura             26.607568     14     44  30.355342   16.0   69.0
# Santa Luzia D'Oeste        26.163265     15     41  30.703297   18.0   53.0
# Seringueiras               25.408696     14     42  31.520000   21.0   47.0
# São Felipe D'Oeste         26.377358     17     41  31.395833   18.0   57.0
# São Francisco do Guaporé   25.828283     14     40  31.870968   19.0   54.0
# São Miguel do Guaporé      26.074324     14     42  33.065789   19.0   60.0
# Teixeirópolis              26.031250     16     39  31.500000   20.0   67.0
# Theobroma                  25.652632     15     42  30.363636   23.0   45.0
# Urupá                      26.621795     15     43  31.356436   17.0   48.0
# Vale do Anari              26.096774     14     44  34.000000   23.0   58.0
# Vale do Paraíso            25.679012     14     52  29.976744   18.0   51.0
# Vilhena                    26.473988     14     44  33.657658   18.0   54.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_marco = sinasc_raw[sinasc_raw.DTNASC.dt.month == 3].copy()
sinasc_marco.groupby('munResNome').aggregate({'QTDFILVIVO': 'sum'}).sort_values('QTDFILVIVO', ascending= False)
# Out:
#                            QTDFILVIVO
# munResNome
# Porto Velho                     812.0
# Ji-Paraná                       155.0
# Ariquemes                       148.0
# Vilhena                         144.0
# Cacoal                          128.0
# Guajará-Mirim                   112.0
# Jaru                             80.0
# Ouro Preto do Oeste              68.0
# Nova Mamoré                      68.0
# Espigão D'Oeste                  61.0
# Buritis                          54.0
# Pimenta Bueno                    51.0
# Rolim de Moura                   50.0
# Machadinho D'Oeste               44.0
# São Miguel do Guaporé            40.0
# São Francisco do Guaporé         36.0
# Candeias do Jamari               35.0
# Costa Marques                    29.0
# Alta Floresta D'Oeste            28.0
# Alto Paraíso                     27.0
# Cujubim                          22.0
# Presidente Médici                21.0
# Alvorada D'Oeste                 20.0
# Seringueiras                     19.0
# Colorado do Oeste                19.0
# Chupinguaia                      19.0
# Nova Brasilândia D'Oeste         18.0
# Monte Negro                      14.0
# Cerejeiras                       14.0
# Urupá                            13.0
# Cacaulândia                      12.0
# Parecis                          11.0
# Corumbiara                       10.0
# Theobroma                         9.0
# Rio Crespo                        9.0
# Mirante da Serra                  9.0
# Campo Novo de Rondônia            9.0
# Itapuã do Oeste                   9.0
# Vale do Anari                     9.0
# Alto Alegre dos Parecis           8.0
# Castanheiras                      7.0
# Vale do Paraíso                   7.0
# Ministro Andreazza                7.0
# Pimenteiras do Oeste              6.0
# Primavera de Rondônia             6.0
# Novo Horizonte do Oeste           6.0
# Cabixi                            5.0
# Governador Jorge Teixeira         5.0
# Nova União                        4.0
# Santa Luzia D'Oeste               3.0
# Teixeirópolis                     1.0
# São Felipe D'Oeste                0.0

# %%
pd.pivot_table(sinasc_raw,index = ['munResNome'], columns=['IDADEPAI'], aggfunc= {'IDADEPAI': ['max', 'min', 'mean']})
# Out:
#                           IDADEPAI                                            \
#                                max
# IDADEPAI                      15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# munResNome
# Alta Floresta D'Oeste          NaN   NaN  17.0  18.0  19.0  20.0  21.0  22.0
# Alto Alegre dos Parecis        NaN  16.0   NaN  18.0  19.0  20.0  21.0  22.0
# Alto Paraíso                   NaN   NaN   NaN   NaN   NaN   NaN  21.0   NaN
# Alvorada D'Oeste               NaN   NaN  17.0  18.0  19.0  20.0  21.0  22.0
# Ariquemes                      NaN   NaN   NaN   NaN   NaN  20.0   NaN   NaN
# Buritis                        NaN   NaN   NaN  18.0  19.0  20.0  21.0   NaN
# Cabixi                         NaN   NaN   NaN   NaN  19.0   NaN   NaN   NaN
# Cacaulândia                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Cacoal                         NaN   NaN  17.0  18.0  19.0  20.0  21.0  22.0
# Campo Novo de Rondônia         NaN   NaN   NaN   NaN   NaN   NaN  21.0  22.0
# Candeias do Jamari             NaN   NaN   NaN   NaN   NaN   NaN  21.0  22.0
# Castanheiras                   NaN   NaN  17.0   NaN  19.0  20.0   NaN   NaN
# Cerejeiras                     NaN   NaN   NaN   NaN  19.0   NaN  21.0  22.0
# Chupinguaia                    NaN   NaN   NaN   NaN   NaN  20.0   NaN  22.0
# Colorado do Oeste              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Corumbiara                     NaN   NaN   NaN   NaN   NaN   NaN  21.0   NaN
# Costa Marques                  NaN   NaN  17.0   NaN  19.0  20.0   NaN  22.0
# Cujubim                        NaN   NaN   NaN   NaN   NaN   NaN  21.0   NaN
# Espigão D'Oeste                NaN  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# Governador Jorge Teixeira      NaN   NaN   NaN   NaN   NaN   NaN   NaN  22.0
# Guajará-Mirim                  NaN   NaN   NaN   NaN  19.0  20.0  21.0   NaN
# Itapuã do Oeste                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Jaru                           NaN   NaN   NaN   NaN  19.0  20.0  21.0  22.0
# Ji-Paraná                     15.0  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# Machadinho D'Oeste             NaN   NaN  17.0  18.0  19.0  20.0  21.0  22.0
# Ministro Andreazza             NaN   NaN   NaN   NaN   NaN   NaN  21.0  22.0
# Mirante da Serra               NaN   NaN   NaN   NaN   NaN  20.0  21.0  22.0
# Monte Negro                    NaN   NaN   NaN   NaN   NaN  20.0   NaN  22.0
# Município ignorado - RO        NaN   NaN   NaN   NaN   NaN   NaN   NaN  22.0
# Nova Brasilândia D'Oeste       NaN   NaN   NaN   NaN   NaN  20.0  21.0  22.0
# Nova Mamoré                    NaN   NaN   NaN   NaN  19.0  20.0   NaN   NaN
# Nova União                     NaN   NaN   NaN  18.0   NaN   NaN  21.0  22.0
# Novo Horizonte do Oeste        NaN   NaN   NaN   NaN   NaN  20.0   NaN  22.0
# Ouro Preto do Oeste            NaN   NaN  17.0  18.0  19.0  20.0  21.0  22.0
# Parecis                        NaN   NaN   NaN  18.0  19.0   NaN  21.0  22.0
# Pimenta Bueno                  NaN  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# Pimenteiras do Oeste           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Porto Velho                    NaN  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# Presidente Médici              NaN  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# Primavera de Rondônia          NaN   NaN   NaN   NaN   NaN   NaN  21.0  22.0
# Rio Crespo                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Rolim de Moura                 NaN  16.0  17.0  18.0  19.0  20.0  21.0  22.0
# Santa Luzia D'Oeste            NaN   NaN   NaN  18.0  19.0  20.0  21.0   NaN
# Seringueiras                   NaN   NaN   NaN   NaN   NaN   NaN  21.0  22.0
# São Felipe D'Oeste             NaN   NaN   NaN  18.0  19.0  20.0  21.0   NaN
# São Francisco do Guaporé       NaN   NaN   NaN   NaN  19.0   NaN   NaN   NaN
# São Miguel do Guaporé          NaN   NaN   NaN   NaN  19.0   NaN  21.0  22.0
# Teixeirópolis                  NaN   NaN   NaN   NaN   NaN  20.0   NaN  22.0
# Theobroma                      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Urupá                          NaN   NaN  17.0   NaN  19.0   NaN  21.0  22.0
# Vale do Anari                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Vale do Paraíso                NaN   NaN   NaN  18.0  19.0  20.0  21.0   NaN
# Vilhena                        NaN   NaN   NaN  18.0   NaN  20.0  21.0   NaN
#
#                                        ...                                \
#                                        ...   min
# IDADEPAI                   23.0  24.0  ...  63.0  64.0  65.0  66.0  67.0
# munResNome                             ...
# Alta Floresta D'Oeste      23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Alto Alegre dos Parecis    23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Alto Paraíso               23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Alvorada D'Oeste           23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Ariquemes                   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Buritis                    23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Cabixi                      NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Cacaulândia                 NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Cacoal                     23.0  24.0  ...   NaN  64.0   NaN  66.0   NaN
# Campo Novo de Rondônia      NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Candeias do Jamari          NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Castanheiras                NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Cerejeiras                 23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Chupinguaia                23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Colorado do Oeste          23.0   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Corumbiara                  NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Costa Marques               NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Cujubim                     NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Espigão D'Oeste            23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Governador Jorge Teixeira  23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Guajará-Mirim               NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Itapuã do Oeste             NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Jaru                       23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Ji-Paraná                  23.0  24.0  ...  63.0   NaN   NaN   NaN   NaN
# Machadinho D'Oeste         23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Ministro Andreazza         23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Mirante da Serra           23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Monte Negro                 NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Município ignorado - RO     NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Nova Brasilândia D'Oeste    NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Nova Mamoré                23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Nova União                  NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Novo Horizonte do Oeste    23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Ouro Preto do Oeste        23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Parecis                     NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Pimenta Bueno              23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Pimenteiras do Oeste        NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Porto Velho                23.0  24.0  ...   NaN   NaN  65.0   NaN   NaN
# Presidente Médici          23.0  24.0  ...   NaN  64.0   NaN   NaN   NaN
# Primavera de Rondônia       NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Rio Crespo                  NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Rolim de Moura             23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Santa Luzia D'Oeste        23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Seringueiras                NaN  24.0  ...   NaN   NaN   NaN   NaN   NaN
# São Felipe D'Oeste         23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# São Francisco do Guaporé   23.0   NaN  ...   NaN   NaN   NaN   NaN   NaN
# São Miguel do Guaporé      23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Teixeirópolis              23.0  24.0  ...   NaN   NaN   NaN   NaN  67.0
# Theobroma                  23.0   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Urupá                      23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Vale do Anari              23.0   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Vale do Paraíso            23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
# Vilhena                    23.0  24.0  ...   NaN   NaN   NaN   NaN   NaN
#
#
#
# IDADEPAI                   68.0  69.0  70.0  73.0  86.0
# munResNome
# Alta Floresta D'Oeste       NaN   NaN   NaN   NaN   NaN
# Alto Alegre dos Parecis     NaN   NaN   NaN   NaN   NaN
# Alto Paraíso                NaN   NaN   NaN   NaN   NaN
# Alvorada D'Oeste            NaN   NaN   NaN   NaN   NaN
# Ariquemes                   NaN   NaN   NaN   NaN   NaN
# Buritis                     NaN   NaN   NaN   NaN   NaN
# Cabixi                      NaN   NaN   NaN   NaN   NaN
# Cacaulândia                 NaN   NaN   NaN   NaN   NaN
# Cacoal                      NaN   NaN   NaN   NaN   NaN
# Campo Novo de Rondônia      NaN   NaN   NaN   NaN   NaN
# Candeias do Jamari          NaN   NaN   NaN   NaN   NaN
# Castanheiras                NaN   NaN   NaN   NaN   NaN
# Cerejeiras                  NaN   NaN   NaN   NaN   NaN
# Chupinguaia                 NaN   NaN   NaN   NaN   NaN
# Colorado do Oeste           NaN   NaN   NaN   NaN   NaN
# Corumbiara                  NaN   NaN   NaN   NaN   NaN
# Costa Marques               NaN   NaN   NaN   NaN   NaN
# Cujubim                     NaN   NaN   NaN   NaN   NaN
# Espigão D'Oeste             NaN   NaN   NaN   NaN  86.0
# Governador Jorge Teixeira   NaN   NaN   NaN   NaN   NaN
# Guajará-Mirim               NaN   NaN   NaN   NaN   NaN
# Itapuã do Oeste             NaN   NaN   NaN  73.0   NaN
# Jaru                        NaN   NaN   NaN   NaN   NaN
# Ji-Paraná                   NaN   NaN   NaN   NaN   NaN
# Machadinho D'Oeste          NaN   NaN   NaN   NaN   NaN
# Ministro Andreazza          NaN   NaN   NaN   NaN   NaN
# Mirante da Serra            NaN   NaN   NaN   NaN   NaN
# Monte Negro                 NaN   NaN   NaN   NaN   NaN
# Município ignorado - RO     NaN   NaN   NaN   NaN   NaN
# Nova Brasilândia D'Oeste    NaN   NaN   NaN   NaN   NaN
# Nova Mamoré                 NaN   NaN   NaN   NaN   NaN
# Nova União                  NaN   NaN   NaN   NaN   NaN
# Novo Horizonte do Oeste     NaN   NaN   NaN   NaN   NaN
# Ouro Preto do Oeste         NaN   NaN   NaN   NaN   NaN
# Parecis                     NaN   NaN   NaN   NaN   NaN
# Pimenta Bueno              68.0   NaN  70.0   NaN   NaN
# Pimenteiras do Oeste        NaN   NaN   NaN   NaN   NaN
# Porto Velho                 NaN   NaN   NaN   NaN   NaN
# Presidente Médici           NaN   NaN   NaN   NaN   NaN
# Primavera de Rondônia       NaN   NaN   NaN   NaN   NaN
# Rio Crespo                  NaN   NaN   NaN   NaN   NaN
# Rolim de Moura              NaN  69.0   NaN   NaN   NaN
# Santa Luzia D'Oeste         NaN   NaN   NaN   NaN   NaN
# Seringueiras                NaN   NaN   NaN   NaN   NaN
# São Felipe D'Oeste          NaN   NaN   NaN   NaN   NaN
# São Francisco do Guaporé    NaN   NaN   NaN   NaN   NaN
# São Miguel do Guaporé       NaN   NaN   NaN   NaN   NaN
# Teixeirópolis               NaN   NaN   NaN   NaN   NaN
# Theobroma                   NaN   NaN   NaN   NaN   NaN
# Urupá                       NaN   NaN   NaN   NaN   NaN
# Vale do Anari               NaN   NaN   NaN   NaN   NaN
# Vale do Paraíso             NaN   NaN   NaN   NaN   NaN
# Vilhena                     NaN   NaN   NaN   NaN   NaN
#
# [53 rows x 174 columns]

# %% [markdown]
# Pode-se concluir que a idade mínima em Porto Velho dos pais são 16 anos e máxima 65 anos, bem como a média, 40 anos.

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Alguns insights extraídos da análise acima:
#
#
#
# *   Aparentemente o peso do bebê não tem relação com o nível de
# escolaridade do filho.
# *   Também não existe um padrão exato quanto à idade do pai e da mãe, ou
# seja, ainda  a maioria dos pais são mais velhos que a mãe, porém não pode-se considerar um padrão.
# *   Por uma pesquisa breve em relação do IDH dos municipios de Rondônia, pode-se dizer que o município de POrto Velho não apenas apresente a maior quantidade de filhos vivos como também o maior IDH do Estado, o que necessitaria de uma avaliação mais precisa porém uma variante relevante.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO     DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo 2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo 2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo 2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo 2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo 2019-03-23
# ...                ...              ...      ...      ...        ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo 2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal 2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo 2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal 2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo 2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# 0      Masculino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 1       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 2       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 3       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# 4       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# ...          ...     ...         ...       ...        ...         ...
# 27023  Masculino  Branca  2020-09-28       NaN     3.2.01  2020-10-13
# 27024  Masculino  Branca  2019-10-16       NaN     3.2.01  2019-10-21
# 27025  Masculino   Parda  2019-08-07       NaN     3.2.00  2019-08-07
# 27026  Masculino   Parda  2020-01-07       NaN     3.2.00  2020-01-07
# 27027  Masculino   Parda  2020-10-15       NaN     3.2.01  2020-10-16
#
#       munResStatus munResTipo               munResNome  munResUf
# 0            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3            ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...            ...        ...                      ...       ...
# 27023        ATIVO      MUNIC                  Vilhena  Rondônia
# 27024        ATIVO      MUNIC              Chupinguaia  Rondônia
# 27025        ATIVO      MUNIC                  Vilhena  Rondônia
# 27026        ATIVO      MUNIC                  Vilhena  Rondônia
# 27027        ATIVO      MUNIC  Novo Horizonte do Oeste  Rondônia
#
# [27028 rows x 15 columns]

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')
